# %%
# Alice and Bob choose one prime number, q and one root number α/g

# prime number
q = 13 # change

# root number
g = 7 # change

#2. Alice chooses a private large random number Xa , and calculates Ya = α ** Xa % q

Xa = 10 # change
Ya = (g ** Xa) % q

print('Alice: ')
print(f'Private, Xa = {Xa}')
print(f'Ya = (g ** Xa) % q = {Ya}')
print("")

# 3. Alice sends the number Ya (public) to Bob
print(f'Ya: {Ya}(public) will send to Bob')
print("")

#4. Bob independently chooses another private large random number Xb and calculates B such that: Yb = α ** Xb mod q

Xb = 20 # change
Yb = (g ** Xb) % q
print('Bob: ')
print(f'Private, Xb = {Xb}')
print(f'Yb = (g ** Xb) % q = {Yb}')
print("")

# 5. Bob sends the number Y B (public) to Alice

print(f'Yb: {Yb}(public) will send to Alic')
print("")

# 6. Alice now computes the secret key K1 as follows: K1 = (Yb ** Xa) mod q
K1 = (Yb ** Xa) % q
print(f"K1 = (Yb ** Xa) % q= {K1}")
print("")

# 7. Bob now computes the secret key K2 as follows: K2 = ( Ya ** Xb) mod q

K2 = (Ya ** Xb) % q
print(f"K2 = (Ya ** Xb) % q = {K2}")
print("")
print("")
print(f"Alice and Bob, Both hold (q: {q}, g: {g})")
print("")
print(f"Alice choose Xa: {Xa} and Bob choose Xb: {Xb}")
print("")
print(f"Alice hold Yb: {Yb} that generate by Bob using Yb = g ** Xb mod q")
print("")
print(f"Bob hold Ya: {Ya} that generate by Alice using Ya = g ** Xa mod q")
print("")
print('Now Alice send a message (12345) to Bob')
print('This message (12345) may encrypt using some method, and K1==K2 as a share secret key')
# Out:
# Alice:
# Private, Xa = 10
# Ya = (g ** Xa) % q = 4
#
# Ya: 4(public) will send to Bob
#
# Bob:
# Private, Xb = 20
# Yb = (g ** Xb) % q = 3
#
# Yb: 3(public) will send to Alic
#
# K1 = (Yb ** Xa) % q= 3
#
# K2 = (Ya ** Xb) % q = 3
#
#
# Alice and Bob, Both hold (q: 13, g: 7)
#
# Alice choose Xa: 10 and Bob choose Xb: 20
#
# Alice hold Yb: 3 that generate by Bob using Yb = g ** Xb mod q
#
# Bob hold Ya: 4 that generate by Alice using Ya = g ** Xa mod q
#
# Now Alice send a message (12345) to Bob
# This message (12345) may encrypt using some method, and K1==K2 as a share secret key

# %%
# Alice and Bob choose one prime number, q and one root number α/g

# prime number
q = 19 # change

# root number
g = 14 # change

#2. Alice chooses a private large random number Xa , and calculates Ya = α ** Xa % q

Xa = 5 # change
Ya = (g ** Xa) % q

print('Alice: ')
print(f'Private, Xa = {Xa}')
print(f'Ya = (g ** Xa) % q = {Ya}')
print("")

# 3. Alice sends the number Ya (public) to Bob
print(f'Ya: {Ya}(public) will send to Bob')
print("")

#4. Bob independently chooses another private large random number Xb and calculates B such that: Yb = α ** Xb mod q

Xb = 7 # change
Yb = (g ** Xb) % q
print('Bob: ')
print(f'Private, Xb = {Xb}')
print(f'Yb = (g ** Xb) % q = {Yb}')
print("")

# 5. Bob sends the number Y B (public) to Alice

print(f'Yb: {Yb}(public) will send to Alic')
print("")

# 6. Alice now computes the secret key K1 as follows: K1 = (Yb ** Xa) mod q
K1 = (Yb ** Xa) % q
print(f"K1 = (Yb ** Xa) % q= {K1}")
print("")

# 7. Bob now computes the secret key K2 as follows: K2 = ( Ya ** Xb) mod q

K2 = (Ya ** Xb) % q
print(f"K2 = (Ya ** Xb) % q = {K2}")
print("")
print("")
print(f"Alice and Bob, Both hold (q: {q}, g: {g})")
print("")
print(f"Alice choose Xa: {Xa} and Bob choose Xb: {Xb}")
print("")
print(f"Alice hold Yb: {Yb} that generate by Bob using Yb = g ** Xb mod q")
print("")
print(f"Bob hold Ya: {Ya} that generate by Alice using Ya = g ** Xa mod q")
print("")
print('Now Alice send a message (12345) to Bob')
print('This message (12345) may encrypt using some method, and K1==K2 as a share secret key')
# Out:
# Alice:
# Private, Xa = 5
# Ya = (g ** Xa) % q = 10
#
# Ya: 10(public) will send to Bob
#
# Bob:
# Private, Xb = 7
# Yb = (g ** Xb) % q = 3
#
# Yb: 3(public) will send to Alic
#
# K1 = (Yb ** Xa) % q= 15
#
# K2 = (Ya ** Xb) % q = 15
#
#
# Alice and Bob, Both hold (q: 19, g: 14)
#
# Alice choose Xa: 5 and Bob choose Xb: 7
#
# Alice hold Yb: 3 that generate by Bob using Yb = g ** Xb mod q
#
# Bob hold Ya: 10 that generate by Alice using Ya = g ** Xa mod q
#
# Now Alice send a message (12345) to Bob
# This message (12345) may encrypt using some method, and K1==K2 as a share secret key

# %%
import string
 
 
# A list containing all characters
all_letters= string.ascii_letters
  
     
"""
create a dictionary to store the substitution
for the given alphabet in the plain text
based on the key
"""
  
     
dict1 = {}
key = 4 # k1 / k2
  
for i in range(len(all_letters)):
    dict1[all_letters[i]] = all_letters[(i+key)%len(all_letters)]
  
  
plain_txt= "I am studying Data Encryption" # to change
cipher_txt=[]
  
# loop to generate ciphertext
  
for char in plain_txt:
    if char in all_letters:
        temp = dict1[char]
        cipher_txt.append(temp)
    else:
        temp =char
        cipher_txt.append(temp)
         
cipher_txt= "".join(cipher_txt)
print("Cipher Text is: ",cipher_txt)
  
     
"""
create a dictionary to store the substitution
for the given alphabet in the cipher
text based on the key
"""
  
     
dict2 = {}    
for i in range(len(all_letters)):
    dict2[all_letters[i]] = all_letters[(i-key)%(len(all_letters))]
      
# loop to recover plain text
decrypt_txt = []
 
for char in cipher_txt:
    if char in all_letters:
        temp = dict2[char]
        decrypt_txt.append(temp)
    else:
        temp = char
        decrypt_txt.append(temp)
         
decrypt_txt = "".join(decrypt_txt)
print("Recovered plain text :", decrypt_txt)
